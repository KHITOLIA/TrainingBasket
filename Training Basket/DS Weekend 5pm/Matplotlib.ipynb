# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('Titanic-Dataset.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head(7)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
(891-177)
# Out:
# 714

# %%
891-687
# Out:
# 204

# %%
df.drop(columns='Cabin', inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df['Age'].isnull().sum()
# Out:
# 177

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Age'][0]
# Out:
# 22.0

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %%
df[df['Age'] == 29.69911764705882]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
df['Embarked'].nunique()
# Out:
# 3

# %%
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].value_counts().idxmax())

# %%
df['Embarked'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df.drop(columns = ['PassengerId', 'Name', 'Ticket'], inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
# slice it to get Fare and Embarked column

# %%
df.iloc[:, [1, 5]]
# Out:
#      Pclass  Parch
# 0         3      0
# 1         1      0
# 2         3      0
# 3         1      0
# 4         3      0
# ..      ...    ...
# 886       2      0
# 887       1      0
# 888       3      2
# 889       1      0
# 890       3      0
#
# [891 rows x 2 columns]

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
# male -> 0 female -> 1

# %%
# map

# %%
# df['Sex'] = df['Sex'].map({'female' : 1, 'male' : 0})

# %%
import numpy as np

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
# df['Sex'] = np.where((df['Sex'] == 'male'), 0, 1)

# %%
# df['Sex'] = df['Sex'].apply(lambda x : 0 if x == 'male' else 1)

# %%
# df['Age'] < 18 -> Adults and > 18 Old age

# %%
# df['child'] = df['Age'].apply(lambda x : 'adults' if x > 18 else 'Old age')

# %%
# df['Embarked'] = df['Embarked'].map({'S': 0, 'C': 1, 'Q': 2})

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
# Group by function

# %%
df.groupby('Sex').size()
# Out:
# Sex
# female    314
# male      577
# dtype: int64

# %%
df.groupby('Sex').count()
# Out:
#         Survived  Pclass  Age  SibSp  Parch  Fare  Embarked
# Sex
# female       314     314  314    314    314   314       314
# male         577     577  577    577    577   577       577

# %%
embarked = df.groupby('Embarked')

# %%
embarked.get_group('C')
# Out:
#      Survived  Pclass     Sex        Age  SibSp  Parch     Fare Embarked
# 1           1       1  female  38.000000      1      0  71.2833        C
# 9           1       2  female  14.000000      1      0  30.0708        C
# 19          1       3  female  29.699118      0      0   7.2250        C
# 26          0       3    male  29.699118      0      0   7.2250        C
# 30          0       1    male  40.000000      0      0  27.7208        C
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 866         1       2  female  27.000000      1      0  13.8583        C
# 874         1       2  female  28.000000      1      0  24.0000        C
# 875         1       3  female  15.000000      0      0   7.2250        C
# 879         1       1  female  56.000000      0      1  83.1583        C
# 889         1       1    male  26.000000      0      0  30.0000        C
#
# [168 rows x 8 columns]

# %%
embarked.get_group('Q')['Fare'].mean()
# Out:
# 13.276029870129872

# %%
# i want to calculate mean of fare whose embarked is Q

# %%
df[df['Embarked'] == 'Q']['Fare'].mean()
# Out:
# 13.276029870129872

# %%
# embarked = S and Pclass = 1

# %%
s_pclass_1 = embarked.get_group('S')

# %%
# s_pclass_1[s_pclass_1['Pclass'] == 1]

# %%
s_pclass_1[s_pclass_1['Pclass'] == 1]
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 3           1       1  female  35.0      1      0   53.1000        S
# 6           0       1    male  54.0      0      0   51.8625        S
# 11          1       1  female  58.0      0      0   26.5500        S
# 23          1       1    male  28.0      0      0   35.5000        S
# 27          0       1    male  19.0      3      2  263.0000        S
# ..        ...     ...     ...   ...    ...    ...       ...      ...
# 862         1       1  female  48.0      0      0   25.9292        S
# 867         0       1    male  31.0      0      0   50.4958        S
# 871         1       1  female  47.0      1      1   52.5542        S
# 872         0       1    male  33.0      0      0    5.0000        S
# 887         1       1  female  19.0      0      0   30.0000        S
#
# [129 rows x 8 columns]

# %%
A = df.groupby(['Sex', 'Embarked', 'Pclass'])

# %%
A.get_group(('male', 'S', 1))
# Out:
#      Survived  Pclass   Sex        Age  SibSp  Parch      Fare Embarked
# 6           0       1  male  54.000000      0      0   51.8625        S
# 23          1       1  male  28.000000      0      0   35.5000        S
# 27          0       1  male  19.000000      3      2  263.0000        S
# 35          0       1  male  42.000000      1      0   52.0000        S
# 55          1       1  male  29.699118      0      0   35.5000        S
# ..        ...     ...   ...        ...    ...    ...       ...      ...
# 815         0       1  male  29.699118      0      0    0.0000        S
# 822         0       1  male  38.000000      0      0    0.0000        S
# 857         1       1  male  51.000000      0      0   26.5500        S
# 867         0       1  male  31.000000      0      0   50.4958        S
# 872         0       1  male  33.000000      0      0    5.0000        S
#
# [79 rows x 8 columns]

# %%
# df[df['Pclass'] == 1]['Pclass'].value_counts()

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
A.get_group(('female', 'C', 3))['Fare'].mean()
# Out:
# 14.694926086956524

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
df[(df['Sex'] == 'male') & (df['Embarked'] == 'S')]
# Out:
#      Survived  Pclass   Sex        Age  SibSp  Parch     Fare Embarked
# 0           0       3  male  22.000000      1      0   7.2500        S
# 4           0       3  male  35.000000      0      0   8.0500        S
# 6           0       1  male  54.000000      0      0  51.8625        S
# 7           0       3  male   2.000000      3      1  21.0750        S
# 12          0       3  male  20.000000      0      0   8.0500        S
# ..        ...     ...   ...        ...    ...    ...      ...      ...
# 878         0       3  male  29.699118      0      0   7.8958        S
# 881         0       3  male  33.000000      0      0   7.8958        S
# 883         0       2  male  28.000000      0      0  10.5000        S
# 884         0       3  male  25.000000      0      0   7.0500        S
# 886         0       2  male  27.000000      0      0  13.0000        S
#
# [441 rows x 8 columns]

# %%
a = df.groupby(['Sex', 'Embarked'])

# %%
a.get_group(('male', 'S'))
# Out:
#      Survived  Pclass   Sex        Age  SibSp  Parch     Fare Embarked
# 0           0       3  male  22.000000      1      0   7.2500        S
# 4           0       3  male  35.000000      0      0   8.0500        S
# 6           0       1  male  54.000000      0      0  51.8625        S
# 7           0       3  male   2.000000      3      1  21.0750        S
# 12          0       3  male  20.000000      0      0   8.0500        S
# ..        ...     ...   ...        ...    ...    ...      ...      ...
# 878         0       3  male  29.699118      0      0   7.8958        S
# 881         0       3  male  33.000000      0      0   7.8958        S
# 883         0       2  male  28.000000      0      0  10.5000        S
# 884         0       3  male  25.000000      0      0   7.0500        S
# 886         0       2  male  27.000000      0      0  13.0000        S
#
# [441 rows x 8 columns]

# %%
df.groupby('Embarked')['Fare'].mean()
# Out:
# Embarked
# C    59.954144
# Q    13.276030
# S    27.243651
# Name: Fare, dtype: float64

# %%
# df[df['Embarked'] == 'C']['Fare'].mean()
# df[df['Embarked'] == 'Q']['Fare'].mean()
# df[df['Embarked'] == 'S']['Fare'].mean()

# %% [markdown]
# # pivot table

# %%
pd.pivot_table(df,values = 'Fare', index = 'Sex', columns='Survived', aggfunc = 'count')
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
df.pivot_table(index = 'Sex', values = 'Fare', aggfunc='count')
# Out:
#         Fare
# Sex
# female   314
# male     577

# %%
df.groupby('Sex').size()
# Out:
# Sex
# female    314
# male      577
# dtype: int64

# %%
df.pivot_table(index = 'Sex', columns = 'Pclass', values = ['Age', 'Fare'], aggfunc='mean')
# Out:
#               Age                              Fare
# Pclass          1          2          3           1          2          3
# Sex
# female  34.141405  28.748661  24.068493  106.125798  21.970121  16.118810
# male    39.287717  30.653908  27.372153   67.226127  19.741782  12.661633

# %%
# female -> pclass = 1 => mean of age and mean of fare

# %%
df.pivot_table(index = ['Pclass', 'Embarked'], columns = 'Sex', values = ['Age', 'Fare'], aggfunc='mean')
# Out:
#                        Age                   Fare
# Sex                 female       male      female       male
# Pclass Embarked
# 1      C         35.313851  38.623683  115.640309  93.536707
#        Q         33.000000  44.000000   90.000000  90.000000
#        S         33.155929  39.581098   98.265834  52.949947
# 2      C         19.142857  26.689824   25.268457  25.421250
#        Q         29.849559  57.000000   12.350000  12.350000
#        S         29.719390  30.790967   21.912687  19.232474
# 3      C         18.821471  26.976840   14.694926   9.352237
#        Q         27.623627  29.140460   10.307833  11.924251
#        S         24.106698  27.176057   18.670077  13.307149

# %%
b = df.groupby(['Sex', 'Embarked', 'Pclass'])

# %%
b.get_group(('female', 'C', 1))['Age'].mean()
# Out:
# 35.313850889192885

# %%
b.get_group(('female', 'C', 1))['Fare'].mean()
# Out:
# 115.64030930232558

# %%
# write a program to find odd or even without using modulus operator

# %%
df
# Out:
#      Survived  Pclass     Sex        Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
# Fare vs Survived

# %%
plt.figure(figsize=(10, 4))
plt.scatter(df['Survived'], df['SibSp'], marker='*', color = 'm')
plt.title('Fare vs Survived')
plt.xlabel('Survived Class')
plt.ylabel('Fare of a Person')
plt.show()

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
sex = ['male','female']
counts = [577, 314]
plt.bar(sex, counts, width=0.5, label = 'Male-Female')
plt.legend()
plt.show()

# %%
count = list(df['Embarked'].value_counts())

# %%
# categories 
count
# Out:
# [646, 168, 77]

# %%
categories = df['Embarked'].value_counts().reset_index()

# %%
categories['Embarked'], categories['count']
# Out:
# (0    S
#  1    C
#  2    Q
#  Name: Embarked, dtype: object,
#  0    646
#  1    168
#  2     77
#  Name: count, dtype: int64)

# %%
plt.bar(categories['Embarked'], categories['count'])
# Out:
# <BarContainer object of 3 artists>

# %%
# Make a bar graph for average age of males and females
# Embarked vs Fare (average Fare for each categories)

# %%
b= df.groupby('Sex')['Age'].mean()

sex= df['Sex'].value_counts().reset_index()['Sex']

plt.bar(sex, b, width=0.5)
# Out:
# <BarContainer object of 2 artists>

# %%
number = int(input('Enter a number'))

if (number // 2) * 2 == number:

    print("Even")

else:

    print("Odd")
# Out:
# Enter a number 345
# Odd

# %%
h = df.groupby('Embarked')['Fare'].mean()

# %%
x = df.groupby('Embarked').size().reset_index()['Embarked']

# %%
plt.bar?
# Out:
# Signature:
# plt.bar(
#     x: 'float | ArrayLike',
#     height: 'float | ArrayLike',
#     width: 'float | ArrayLike' = 0.8,
#     bottom: 'float | ArrayLike | None' = None,
#     *,
#     align: "Literal['center', 'edge']" = 'center',
#     data=None,
#     **kwargs,
# ) -> 'BarContainer'
# Docstring:
# Make a bar plot.
#
# The bars are positioned at *x* with the given *align*\ment. Their
# dimensions are given by *height* and *width*. The vertical baseline
# is *bottom* (default 0).
#
# Many parameters can take either a single value applying to all bars
# or a sequence of values, one for each bar.
#
# Parameters
# ----------
# x : float or array-like
#     The x coordinates of the bars. See also *align* for the
#     alignment of the bars to the coordinates.
#
# height : float or array-like
#     The height(s) of the bars.
#
#     Note that if *bottom* has units (e.g. datetime), *height* should be in
#     units that are a difference from the value of *bottom* (e.g. timedelta).
# ...
