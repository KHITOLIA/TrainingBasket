# %%
import pandas as pd
from sklearn.datasets import fetch_openml
from sklearn.feature_selection import chi2
from sklearn.preprocessing import LabelEncoder
from sklearn.datasets import load_wine

# %%
df = pd.read_csv('Titanic-Dataset.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop(columns = ['Cabin'], inplace = True)

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.shape
# Out:
# (891, 11)

# %%
categorical_data = df[['Sex', 'SibSp', 'Parch', 'Embarked']].dropna()

# %%
categorical_data.head()
# Out:
#       Sex  SibSp  Parch Embarked
# 0    male      1      0        S
# 1  female      1      0        C
# 2  female      0      0        S
# 3  female      1      0        S
# 4    male      0      0        S

# %%
le = LabelEncoder()

# %%
le
# Out:
# LabelEncoder()

# %%
for col in categorical_data.columns:
    categorical_data[col] = le.fit_transform(categorical_data[col])

# %%
categorical_data.head(10)
# Out:
#    Sex  SibSp  Parch  Embarked
# 0    1      1      0         2
# 1    0      1      0         0
# 2    0      0      0         2
# 3    0      1      0         2
# 4    1      0      0         2
# 5    1      0      0         1
# 6    1      0      0         2
# 7    1      3      1         2
# 8    0      0      2         2
# 9    0      1      0         0

# %%
y = df['Survived'].dropna()

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
X = categorical_data

# %%
chi_statistics , p_value = chi2(X, y)

# %%
chi_statistics
# Out:
# array([92.70244698,  1.23604038, 10.09749911, 10.20252466])

# %%
p_value
# Out:
# array([6.07783826e-22, 2.66235537e-01, 1.48470676e-03, 1.40248517e-03])

# %%
for i in range(len(p_value)):
    if p_value[i] < 0.05:
        print(categorical_data.columns[i])
# Out:
# Sex
# Parch
# Embarked
